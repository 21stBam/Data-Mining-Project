# %% [markdown]
# # Data Mining Project
# by Obsa Aba-waji Mirnary Carbajal
#
# ## Experiment 1: Linear Regression
# In this notebook, we will be looking at a comparison of gas prices with fuel economy. Our hypothesis is that increases in gas prices are what drive the increase in improvements of fuel economy.

# %% [markdown]
# ## Importing Libs and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
vehicles = pd.read_csv('data/vehicles.csv', dtype=object)
gas_all_prices = pd.read_csv('data/GASALLCOVW.csv', index_col=0)
gas_reg_prices = pd.read_csv('data/GASREGCOVW.csv', index_col=0)
gas_prem_prices = pd.read_csv('data/GASPRMCOVW.csv', index_col=0)

# %% [markdown]
# ## Check to see that Data has been loaded
#
# Looking at the head of the data to make sure that the data has been loaded into their dataframes.

# %%
vehicles.head()
# Out:
#             barrels08 barrelsA08 charge120 charge240 city08 city08U cityA08  \
# 0  15.695714285714287        0.0       0.0       0.0     19     0.0       0
# 1   29.96454545454546        0.0       0.0       0.0      9     0.0       0
# 2  12.207777777777778        0.0       0.0       0.0     23     0.0       0
# 3   29.96454545454546        0.0       0.0       0.0     10     0.0       0
# 4  17.347894736842107        0.0       0.0       0.0     17     0.0       0
#
#   cityA08U cityCD cityE   ...    mfrCode c240Dscr charge240b c240bDscr  \
# 0      0.0    0.0   0.0   ...        NaN      NaN        0.0       NaN
# 1      0.0    0.0   0.0   ...        NaN      NaN        0.0       NaN
# 2      0.0    0.0   0.0   ...        NaN      NaN        0.0       NaN
# 3      0.0    0.0   0.0   ...        NaN      NaN        0.0       NaN
# 4      0.0    0.0   0.0   ...        NaN      NaN        0.0       NaN
#
#                       createdOn                    modifiedOn startStop  \
# 0  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013       NaN
# 1  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013       NaN
# 2  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013       NaN
# 3  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013       NaN
# 4  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013       NaN
#
#   phevCity phevHwy phevComb
# 0        0       0        0
# 1        0       0        0
# 2        0       0        0
# 3        0       0        0
# 4        0       0        0
#
# [5 rows x 83 columns]

# %%
gas_all_prices.head()
# Out:
#             GASALLCOVW
# DATE
# 1994-11-28       1.175
# 1994-12-05       1.143
# 1994-12-12       1.118
# 1994-12-19       1.099
# 1994-12-26       1.088

# %%
gas_reg_prices.head()
# Out:
#            GASREGCOVW
# DATE
# 1990-08-20      1.191
# 1990-08-27      1.245
# 1990-09-03      1.242
# 1990-09-10      1.252
# 1990-09-17      1.266

# %%
gas_prem_prices.head()
# Out:
#             GASPRMCOVW
# DATE
# 1994-11-28       1.270
# 1994-12-05       1.260
# 1994-12-12       1.244
# 1994-12-19       1.233
# 1994-12-26       1.222

# %% [markdown]
# ## Cleaning up vehicles data
#
# The vehicles data has a lot of fields that we will not be needing and is not ogranized in a logical manner for our needs.

# %%
columns_for_vehicles = ['year',
                        'make',
                        'model',
                        'VClass',
                        'fuelType',
                        'fuelType1',
                        'city08',
                        'city08U',
                        'highway08',
                        'highway08U',
                        'comb08',
                        'comb08U',]
vehicles = vehicles[columns_for_vehicles]
vehicles.head()
# Out:
#    year        make                model           VClass fuelType  \
# 0  1985  Alfa Romeo   Spider Veloce 2000      Two Seaters  Regular
# 1  1985     Ferrari           Testarossa      Two Seaters  Regular
# 2  1985       Dodge              Charger  Subcompact Cars  Regular
# 3  1985       Dodge  B150/B250 Wagon 2WD             Vans  Regular
# 4  1993      Subaru     Legacy AWD Turbo     Compact Cars  Premium
#
#           fuelType1 city08 city08U highway08 highway08U comb08 comb08U
# 0  Regular Gasoline     19     0.0        25        0.0     21     0.0
# 1  Regular Gasoline      9     0.0        14        0.0     11     0.0
# 2  Regular Gasoline     23     0.0        33        0.0     27     0.0
# 3  Regular Gasoline     10     0.0        12        0.0     11     0.0
# 4  Premium Gasoline     17     0.0        23        0.0     19     0.0

# %% [markdown]
# ## Cleaning up Gasoline data
#
# The next piece of data we need to clean up is our gas prices data. Our vehicle data has years prior to 1993, but the data is not complete, so we will be focusing on gas prices starting in 1994.

# %%
print(len(gas_reg_prices))
print(len(gas_prem_prices))
print(len(gas_all_prices))
# Out:
# 1418
# 1195
# 1195

# %%
temp = gas_all_prices.join(gas_prem_prices)
joined_gas_prices = temp.join(gas_reg_prices)

# %%
joined_gas_prices.head()
# Out:
#             GASALLCOVW  GASPRMCOVW GASREGCOVW
# DATE
# 1994-11-28       1.175       1.270      1.082
# 1994-12-05       1.143       1.260      1.075
# 1994-12-12       1.118       1.244      1.064
# 1994-12-19       1.099       1.233      1.056
# 1994-12-26       1.088       1.222      1.044

# %%
joined_gas_prices.tail()
# Out:
#             GASALLCOVW  GASPRMCOVW GASREGCOVW
# DATE
# 2017-09-18       2.678       3.112      2.559
# 2017-09-25       2.629       3.069      2.508
# 2017-10-02       2.614       3.055      2.493
# 2017-10-09       2.547       2.986      2.426
# 2017-10-16       2.532       2.964      2.413
